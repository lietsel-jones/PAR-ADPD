# %% [markdown]
# # Prepare AD Summary Statistics
# * Project: Cross-ancestry PAR analysis
# * Version: Python/3.9
# * Last Updated: 05-JUN-2024

# %% [markdown]
# ## Notebook Overview
# * Calculate population attributable risk for each target
# * Generate table with summary statistics and PAR

# %%
# Import packages
import os
import glob
import numpy as np
import pandas as pd
import sys
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date

# %% [markdown]
# ### Import most recent processed data

# %%
# Define path that contains data for analysis
read_path = '{WORK_DIR}/AD/processed/'

# Use glob to find all CSV files in the directory
csv_files = glob.glob(os.path.join(read_path, '*.csv'))

# Sort the files by modification date (newest first)
csv_files.sort(key=os.path.getmtime, reverse=True)

# Read the most recent CSV file into a new DataFrame
if csv_files:
    most_recent_file = csv_files[0]
    df = pd.read_csv(most_recent_file)
    print(f'Most recent file read: {most_recent_file}')
    print(df)
else:
    print('No CSV files found in the specified path.')

# %% [markdown]
# ### Calculate population attributable risk for each target

# %%
# Negative beta -> flipped alleles, new maf = 1 - maf
df['eaf_risk'] = df['effect_allele_frequency'].where(df['beta'] > 0, 1 - df['effect_allele_frequency'])

# Absolute value of beta
df['beta_abs'] = df['beta'].abs()

# Risk allele
df['risk_allele'] = np.where(df['beta'] < 0, df['other_allele'], df['effect_allele'])

# Calculate the new odds ratio with beta_abs
df['odds_ratio_new'] = np.exp(df['beta_abs'])

#Calculate the population attributable risk (PAR = MAF(OR - 1)/1 + MAF(OR - 1))
df['par'] = (df['eaf_risk']*(df['odds_ratio_new']-1)) / (1 + df['eaf_risk']*(df['odds_ratio_new']-1))

# %%
eur = df[df["ancestry"] == 'European']

top_eur = eur.nlargest(n=20, columns='par')
top_eur
# Out:
#                   Locus          SNP  Chromosome   Position effect_allele  \
# 30                 APOE    rs1065853          19   44909976             T
# 6                 CASS4  rs113221226          20   56449045             A
# 15    HLA-DRB1;HLA-DQA1   rs35472547           6   32592593             T
# 8                   CLU    rs1532278           8   27608798             T
# 29                 APOE    rs1081105          19   44909698             A
# 27              TSPAN14    rs7922621          10   80491788             A
# 24              SLC24A4   rs36026988          14   92472038             T
# 20           PICALM;EED    rs9787874          11   86149263             A
# 19               MS4A6A    rs2278867          11   60175636             A
# 14            EPHA1-AS1   rs11771145           7  143413669             A
# 28               PMS2P1    rs7384878           7  100334426             T
# 2                ADAM10     rs653765          15   58749813             T
# 0                 ABCA7   rs12151021          19    1050875             A
# 17               KANSL1    rs7225002          17   46111701             A
# 5          BIN1;CYP27C1   rs34779859           2  127135192             T
# 12                DOC2A    rs1140239          16   30010081             T
# 1                   ACE       rs4311          17   63483402             T
# 13  LOC107984208;ECHDC3    rs7912495          10   11676714             A
# 25          PSMC3;RAPSN    rs4434960          11   47433000             A
# 10                  CR1   rs10779336           1  207625371             T
#
#    other_allele    beta        p_value  effect_allele_frequency  ancestry  \
# 30            G -0.6908  2.850000e-174                   0.0589  European
# 6             G -0.1264   1.890000e-11                   0.0807  European
# 15            G -0.0869   4.923000e-09                   0.1479  European
# 8             C -0.1092   1.048000e-25                   0.3768  European
# 29            C -0.9599  3.850000e-295                   0.9582  European
# 27            C  0.0802   3.990000e-10                   0.8017  European
# 24            C  0.0802   1.567000e-10                   0.7905  European
# 20            G  0.1047   3.381000e-25                   0.5291  European
# 19            T  0.0875   2.783000e-17                   0.6034  European
# 14            G -0.0748   1.810000e-12                   0.3459  European
# 28            C  0.0695   3.351000e-10                   0.6925  European
# 2             C  0.0657   6.408000e-09                   0.7223  European
# 0             G  0.1226   7.692000e-30                   0.3391  European
# 17            G  0.0683   1.111000e-10                   0.6016  European
# 5             G  0.1259   9.070000e-30                   0.3013  European
# 12            C -0.0599   3.269000e-08                   0.3682  European
# 1             C -0.0620   8.077000e-10                   0.4911  European
# 13            G -0.0605   2.835000e-09                   0.5326  European
# 25            T -0.0688   1.774000e-11                   0.5930  European
# 10            G  0.1373   1.753000e-27                   0.1969  European
#
#     eaf_risk  beta_abs risk_allele  odds_ratio_new       par
# 30    0.9411    0.6908           G        1.995311  0.483654
# 6     0.9193    0.1264           G        1.134736  0.110212
# 15    0.8521    0.0869           G        1.090788  0.071805
# 8     0.6232    0.1092           C        1.115385  0.067084
# 29    0.0418    0.9599           C        2.611435  0.063107
# 27    0.8017    0.0802           A        1.083504  0.062745
# 24    0.7905    0.0802           T        1.083504  0.061922
# 20    0.5291    0.1047           A        1.110377  0.055178
# 19    0.6034    0.0875           A        1.091442  0.052291
# 14    0.6541    0.0748           G        1.077669  0.048347
# 28    0.6925    0.0695           T        1.071972  0.047474
# 2     0.7223    0.0657           T        1.067906  0.046755
# 0     0.3391    0.1226           A        1.130432  0.042356
# 17    0.6016    0.0683           A        1.070686  0.040790
# 5     0.3013    0.1259           T        1.134169  0.038854
# 12    0.6318    0.0599           C        1.061730  0.037537
# 1     0.5089    0.0620           C        1.063962  0.031524
# 13    0.4674    0.0605           G        1.062368  0.028325
# 25    0.4070    0.0688           T        1.071222  0.028171
# 10    0.1969    0.1373           T        1.147172  0.028162

# %%
afr = df[df["ancestry"] == 'Black/African American']

top_afr = afr.nlargest(n=20, columns='par')
top_afr
# Out:
#            Locus         SNP  Chromosome   Position effect_allele  \
# 40          APOE      rs7412          19   45412079             T
# 39          APOE    rs429358          19   45411941             T
# 38       TSPAN14   rs7922621          10   82251544             A
# 37        TRANK1   rs9867455           3   36953424             A
# 34        PICALM   rs9787874          11   85860305             A
# 32         CD2AP   rs7738044           6   47469273             A
# 31          BIN1  rs34779859           2  127892768             T
# 36          SPI1   rs4434960          11   47454551             A
# 35  SCIMP/RABEP1  rs57402520          17    5139807             A
# 33           MME  rs61762319           3  154801978             A
#
#    other_allele    beta       p_value  effect_allele_frequency  \
# 40            C -0.4585  2.544000e-12                   0.1059
# 39            C -0.8237  2.591000e-60                   0.7542
# 38            C  0.1577  3.986000e-02                   0.9300
# 37            T -0.1071  7.598000e-03                   0.3260
# 34            G  0.0851  2.684000e-02                   0.5445
# 32            G -0.1012  1.092000e-02                   0.6669
# 31            G  0.1430  1.698000e-02                   0.2221
# 36            T -0.1187  1.149000e-02                   0.7978
# 35            G  0.1443  6.655000e-03                   0.1479
# 33            G -0.8326  3.729000e-02                   0.9935
#
#                   ancestry  eaf_risk  beta_abs risk_allele  odds_ratio_new  \
# 40  Black/African American    0.8941    0.4585           C        1.581700
# 39  Black/African American    0.2458    0.8237           C        2.278916
# 38  Black/African American    0.9300    0.1577           A        1.170815
# 37  Black/African American    0.6740    0.1071           T        1.113046
# 34  Black/African American    0.5445    0.0851           A        1.088826
# 32  Black/African American    0.3331    0.1012           G        1.106498
# 31  Black/African American    0.2221    0.1430           T        1.153730
# 36  Black/African American    0.2022    0.1187           T        1.126032
# 35  Black/African American    0.1479    0.1443           A        1.155231
# 33  Black/African American    0.0065    0.8326           G        2.299289
#
#          par
# 40  0.342148
# 39  0.239172
# 38  0.137081
# 37  0.070798
# 34  0.046134
# 32  0.034259
# 31  0.033016
# 36  0.024850
# 35  0.022443
# 33  0.008375

# %%
ea = df[df['ancestry'] == 'East Asian']

top_ea = ea.nlargest(n=20, columns='par')
top_ea
# Out:
#      Locus        SNP  Chromosome   Position effect_allele other_allele  \
# 46    APOE     rs7412          19   45412079             T            C
# 45    APOE   rs429358          19   45411941             C            T
# 44   SORL1  rs3781837          11  121448972             C            T
# 41     CLU  rs1532278           8   27466315             T            C
# 43  PICALM  rs9787874          11   85860305             G            A
# 42  KANSL1  rs7225002          17   44189067             A            G
#
#         beta        p_value  effect_allele_frequency    ancestry  eaf_risk  \
# 46 -0.514666   2.545000e-08                  0.02701  East Asian   0.97299
# 45  1.220535  1.090000e-134                  0.24280  East Asian   0.24280
# 44 -0.250643   2.964000e-10                  0.21390  East Asian   0.78610
# 41 -0.128515   5.621000e-04                  0.26080  East Asian   0.73920
# 43 -0.138917   3.576000e-05                  0.40580  East Asian   0.59420
# 42  0.079735   1.649000e-02                  0.50670  East Asian   0.50670
#
#     beta_abs risk_allele  odds_ratio_new       par
# 46  0.514666           C        1.673080  0.395734
# 45  1.220535           C        3.389000  0.367108
# 44  0.250643           T        1.284852  0.182954
# 41  0.128515           C        1.137139  0.092042
# 43  0.138917           A        1.149029  0.081349
# 42  0.079735           A        1.083000  0.040359

# %%
ch = df[df['ancestry'] == 'Latino']

top_ch = ch.nlargest(n=20, columns='par')
top_ch
# Out:
#      Locus         SNP  Chromosome  Position effect_allele other_allele  \
# 49    APOE    rs429358          19  45411941             C            T
# 48  PICALM   rs9787874          11  85860305             G            A
# 47   ABCA7  rs12151021          19   1050874             A            G
#
#         beta       p_value  effect_allele_frequency ancestry  eaf_risk  \
# 49  0.716317  5.494160e-14                 0.210868   Latino  0.210868
# 48 -0.184856  1.626850e-02                 0.447227   Latino  0.552773
# 47  0.184236  1.996690e-02                 0.337433   Latino  0.337433
#
#     beta_abs risk_allele  odds_ratio_new       par
# 49  0.716317           C        2.046880  0.180834
# 48  0.184856           A        1.203045  0.100912
# 47  0.184236           A        1.202300  0.063901

# %% [markdown]
# ## T-test

# %%
from scipy import stats
from scipy.stats import ttest_ind
from itertools import combinations

# Get unique studies
studies = df['ancestry'].unique()

# Perform pairwise t-tests
results = []
for cat1, cat2 in combinations(studies, 2):
    group1 = df[df['ancestry'] == cat1]['par']
    group2 = df[df['ancestry'] == cat2]['par']
    
    t_stat, p_value = ttest_ind(group1, group2)
    results.append({'Category1': cat1, 'Category2': cat2, 'T-statistic': t_stat, 'P-value': p_value})

# Convert results to DataFrame
results_df = pd.DataFrame(results)

print(results_df)
# Out:
#                 Category1               Category2  T-statistic   P-value
# 0                European  Black/African American    -1.319935  0.194552
# 1                European              East Asian    -3.276091  0.002379
# 2                European                  Latino    -1.267900  0.213982
# 3  Black/African American              East Asian    -1.474253  0.162543
# 4  Black/African American                  Latino    -0.283200  0.782282
# 5              East Asian                  Latino     0.827194  0.435415

# %% [markdown]
# ### Generate tables with summary statistics and PAR

# %%
# Top 20, not filtered by p-value
top_all = pd.concat([top_eur, top_afr, top_ea, top_ch])

# %%
# Top 20, filtered by p-value
df_filt = df[df.p_value < 0.05]

eur_filt = df_filt[df_filt['ancestry'] == 'European']
top_eur_filt = eur_filt.nlargest(n=20, columns='par')

afr_filt = df_filt[df_filt['ancestry'] == 'Black/African American']
top_afr_filt = afr_filt.nlargest(n=20, columns='par')

ea_filt = df_filt[df_filt['ancestry'] == 'East Asian']
top_ea_filt = ea_filt.nlargest(n=20, columns='par')

lat_filt = df_filt[df_filt['ancestry'] == 'Latino']
top_lat_filt = lat_filt.nlargest(n=20, columns='par')

top_all_filt = pd.concat([top_eur_filt, top_afr_filt, top_ea_filt, top_lat_filt])

# %% [markdown]
# ### Export results to csv

# %%
# Get current date in YYYY-MM-DD format
current_date = datetime.now().strftime('%Y-%m-%d')

# Define the specific path to save the files
save_path = '{WORK_DIR}/AD/results/' 

# List of dataframes and their filenames
dataframes = [(df, f'{current_date}_AD_PAR_results.csv'),
              (top_all, f'{current_date}_AD_PAR_results_top20.csv.csv'),
              (top_all_filt, f'{current_date}_AD_PAR_results_top20_filtered.csv')]

# Export each dataframe to CSV at the specific path
for df, filename in dataframes:
    full_path = os.path.join(save_path, filename)
    df.to_csv(full_path, index=False, header=True)
    print(f'DataFrame exported to {full_path}')
