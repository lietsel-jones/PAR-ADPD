# %% [markdown]
# # Calculate PAR for PD-related targets
# * Project: Cross-ancestry PAR analysis
# * Version: Python/3.9
# * Last Updated: 05-JUN-2024

# %% [markdown]
# ## Notebook Overview
# * Calculate population attributable risk for each target
# * Generate table with summary statistics and PAR

# %%
# Import packages
import os
import glob
import numpy as np
import pandas as pd
import sys
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date

# %% [markdown]
# ### Import most recent processed data

# %%
# Define path that contains data for analysis
read_path = '{WORK_DIR}/PD/processed/'

# Use glob to find all CSV files in the directory
csv_files = glob.glob(os.path.join(read_path, '*.csv'))

# Sort the files by modification date (newest first)
csv_files.sort(key=os.path.getmtime, reverse=True)

# Read the most recent CSV file into a new DataFrame
if csv_files:
    most_recent_file = csv_files[0]
    df = pd.read_csv(most_recent_file)
    print(f'Most recent file read: {most_recent_file}')
    print(df)
else:
    print('No CSV files found in the specified path.')

# %% [markdown]
# ### Calculate population attributable risk for each target

# %%
# Negative beta -> flipped alleles, new maf = 1 - maf
df['eaf_risk'] = df['effect_allele_frequency'].where(df['beta'] > 0, 1 - df['effect_allele_frequency'])

# Absolute value of beta
df['beta_abs'] = df['beta'].abs()

# Risk allele
df['risk_allele'] = np.where(df['beta'] < 0, df['other_allele'], df['effect_allele'])

# Calculate the new odds ratio with beta_abs
df['odds_ratio_new'] = np.exp(df['beta_abs'])

#Calculate the population attributable risk (PAR = MAF(OR - 1)/1 + MAF(OR - 1))
df['par'] = (df['eaf_risk']*(df['odds_ratio_new']-1)) / (1 + df['eaf_risk']*(df['odds_ratio_new']-1))

# %%
# CRHR1 is always MAPT, GBAP1 -> GBA1
df['Locus'] = df['Locus'].replace({'CRHR1':'MAPT'})
df['Locus'] = df['Locus'].replace({'GBAP1':'GBA1'})

# %%
eur = df[df["ancestry"] == 'European']

top_eur = eur.nlargest(n=20, columns='par')
top_eur
# Out:
#            Locus          SNP  Chromosome   Position effect_allele
# 79          MAPT   rs62053943          17   45666837             T  \
# 80          MAPT  rs117615688          17   45720942             A
# 21           GAK     rs873786           4     931588             T
# 37      HLA-DRB5  rs112485576           6   32610995             A
# 42  GS1-124K5.11   rs76949143           7   66544864             A
# 20         MCCC1   rs10513789           3  183042285             T
# 28          SNCA     rs356182           4   89704960             A
# 74          CHD9   rs10221156          16   52935514             A
# 68        VPS13C    rs2251086          15   61705186             T
# 9          KCNS3   rs76116224           2   17966582             A
# 34       C5orf24   rs11950533           5  134863415             A
# 54        RNF141    rs7938782          11   10537230             A
# 24         LCORL   rs34025766           4   17967188             A
# 43          CTSB    rs1293298           8   11854934             A
# 83        DNAH17     rs666463          17   78429399             A
# 44         FGF20     rs620513           8   16840084             T
# 5         NUCKS1     rs823118           1  205754444             T
# 41         GPNMB     rs199351           7   23260430             A
# 7          ITPKB    rs4653767           1  226728377             T
# 71        SETD1A   rs11150601          16   30966478             A
#
#    other_allele    beta        p_value  effect_allele_frequency  ancestry
# 79            C -0.2700   3.584000e-68                   0.1552  European  \
# 80            G -0.2324   6.711000e-16                   0.0670  European
# 21            C -0.1731   1.793000e-21                   0.0988  European
# 37            C -0.1676   6.960000e-28                   0.1630  European
# 42            T -0.1432   1.426000e-08                   0.0507  European
# 20            G  0.1485   1.221000e-34                   0.8112  European
# 28            G -0.2774  3.890000e-154                   0.6278  European
# 74            G -0.1156   1.082000e-10                   0.0932  European
# 68            C -0.1186   6.077000e-18                   0.1417  European
# 9             T  0.1104   1.266000e-08                   0.9042  European
# 34            C -0.0916   7.161000e-09                   0.1020  European
# 54            G  0.0870   2.123000e-09                   0.8776  European
# 24            T -0.0839   2.865000e-10                   0.1589  European
# 43            C  0.0930   3.989000e-16                   0.7444  European
# 83            T  0.0760   3.201000e-09                   0.8328  European
# 44            G -0.0856   2.717000e-15                   0.2682  European
# 5             C  0.1066   1.107000e-29                   0.5660  European
# 41            C  0.1016   5.252000e-26                   0.5939  European
# 7             C  0.0833   1.375000e-15                   0.7196  European
# 71            G  0.0907   5.116000e-20                   0.6442  European
#
#     eaf_risk  beta_abs risk_allele  odds_ratio_new       par
# 79    0.8448    0.2700           C        1.309964  0.207518
# 80    0.9330    0.2324           G        1.261624  0.196203
# 21    0.9012    0.1731           C        1.188985  0.145528
# 37    0.8370    0.1676           C        1.182464  0.132488
# 42    0.9493    0.1432           T        1.153961  0.127517
# 20    0.8112    0.1485           T        1.160093  0.114940
# 28    0.3722    0.2774           G        1.319694  0.106337
# 74    0.9068    0.1156           G        1.122547  0.100012
# 68    0.8583    0.1186           C        1.125919  0.097535
# 9     0.9042    0.1104           A        1.116725  0.095467
# 34    0.8980    0.0916           C        1.095926  0.079310
# 54    0.8776    0.0870           A        1.090897  0.073878
# 24    0.8411    0.0839           T        1.087520  0.068566
# 43    0.7444    0.0930           A        1.097462  0.067643
# 83    0.8328    0.0760           A        1.078963  0.061702
# 44    0.7318    0.0856           G        1.089370  0.061387
# 5     0.5660    0.1066           T        1.112489  0.059858
# 41    0.5939    0.1016           A        1.106941  0.059719
# 7     0.7196    0.0833           T        1.086868  0.058832
# 71    0.6442    0.0907           A        1.094940  0.057636

# %%
afr = df[df["ancestry"] == 'African/African Admixed']

top_afr = afr.nlargest(n=20, columns='par')
top_afr
# Out:
#             Locus         SNP  Chromosome   Position effect_allele
# 93          RAB29  rs11557080           1  205768611             A  \
# 133          GBF1  rs10748818          10  102255522             A
# 105         MCCC1  rs10513789           3  183042285             T
# 166          GBA1   rs3115534           1  155235878             T
# 148        VPS13C   rs2251086          15   61705186             T
# 157      FAM171A2    rs850738          17   44357262             A
# 160        DNAH17    rs666463          17   78429399             A
# 112          SNCA    rs356182           4   89704960             A
# 159         BRIP1  rs61169879          17   61840005             T
# 122           FYN    rs997368           6  111922088             A
# 135        RNF141   rs7938782          11   10537230             A
# 108         LCORL  rs34025766           4   17967188             A
# 97         MAP4K4  rs11683001           2  101780501             A
# 161         ASXL3   rs1941685          18   33724354             T
# 129        SH3GL2  rs13294100           9   17579692             T
# 121         RIMS1  rs12528068           6   71778059             T
# 107          BST1   rs4698412           4   15735725             A
# 139        SCAF11   rs7134559          12   46025303             T
# 111  FAM47E-STBD1   rs6854006           4   76276901             T
# 162          RIT2  rs12456492          18   43093415             A
#
#     other_allele    beta       p_value  effect_allele_frequency
# 93             G -0.3481  1.540000e-01                   0.0503  \
# 133            G  0.1870  1.233000e-02                   0.8696
# 105            G  0.1727  6.314000e-03                   0.8122
# 166            G -0.4494  2.397000e-14                   0.7816
# 148            C -0.1192  1.957000e-02                   0.3778
# 157            G -0.1049  7.846000e-02                   0.2905
# 160            T  0.0889  1.856000e-01                   0.8391
# 112            G -0.2188  2.481000e-05                   0.6818
# 159            C -0.0790  4.237000e-01                   0.0792
# 122            G  0.2066  2.744000e-04                   0.3057
# 135            G  0.0945  6.552000e-02                   0.6618
# 108            T -0.1061  3.149000e-02                   0.4289
# 97             T -0.0676  3.669000e-01                   0.1367
# 161            G  0.0675  2.373000e-01                   0.7489
# 129            G -0.1849  2.815000e-03                   0.7672
# 121            C  0.1037  3.324000e-02                   0.4097
# 107            G -0.0483  4.964000e-01                   0.1696
# 139            C -0.0456  5.950000e-01                   0.1281
# 111            C  0.0852  7.481000e-02                   0.4526
# 162            G -0.1282  1.423000e-02                   0.7090
#
#                     ancestry  eaf_risk  beta_abs risk_allele  odds_ratio_new
# 93   African/African Admixed    0.9497    0.3481           G        1.416374  \
# 133  African/African Admixed    0.8696    0.1870           A        1.205627
# 105  African/African Admixed    0.8122    0.1727           T        1.188509
# 166  African/African Admixed    0.2184    0.4494           G        1.567371
# 148  African/African Admixed    0.6222    0.1192           C        1.126595
# 157  African/African Admixed    0.7095    0.1049           G        1.110600
# 160  African/African Admixed    0.8391    0.0889           A        1.092971
# 112  African/African Admixed    0.3182    0.2188           G        1.244582
# 159  African/African Admixed    0.9208    0.0790           C        1.082204
# 122  African/African Admixed    0.3057    0.2066           A        1.229491
# 135  African/African Admixed    0.6618    0.0945           A        1.099109
# 108  African/African Admixed    0.5711    0.1061           T        1.111933
# 97   African/African Admixed    0.8633    0.0676           T        1.069937
# 161  African/African Admixed    0.7489    0.0675           T        1.069830
# 129  African/African Admixed    0.2328    0.1849           G        1.203098
# 121  African/African Admixed    0.4097    0.1037           T        1.109268
# 107  African/African Admixed    0.8304    0.0483           G        1.049485
# 139  African/African Admixed    0.8719    0.0456           C        1.046656
# 111  African/African Admixed    0.4526    0.0852           T        1.088935
# 162  African/African Admixed    0.2910    0.1282           G        1.136780
#
#           par
# 93   0.283375
# 133  0.151689
# 105  0.132778
# 166  0.110252
# 148  0.073016
# 157  0.072761
# 160  0.072367
# 112  0.072207
# 159  0.070367
# 122  0.065556
# 135  0.061553
# 108  0.060084
# 97   0.056939
# 161  0.049697
# 129  0.045147
# 121  0.042849
# 107  0.039471
# 139  0.039089
# 111  0.038694
# 162  0.038279

# %%
ea = df[df['ancestry'] == 'East Asian']

top_ea = ea.nlargest(n=20, columns='par')
top_ea
# Out:
#             Locus          SNP  Chromosome   Position effect_allele
# 192      HLA-DRB5  rs112485576           6   32578772             A  \
# 227         ASXL3    rs1941685          18   31304318             T
# 169         RAB29   rs11557080           1  205737739             A
# 215        VPS13C    rs2251086          15   61997385             C
# 170         ITPKB    rs4653767           1  226916078             C
# 187         CLCN3   rs62333164           4  170583157             A
# 205          DLG2   rs12283611          11   83487277             A
# 216        SETD1A   rs11150601          16   30977799             A
# 179         MCCC1   rs10513789           3  182760073             G
# 183        SCARB2    rs6825004           4   77110365             G
# 182         LCORL   rs34025766           4   17968811             A
# 218        CASC16    rs3104783          16   52636242             A
# 194           FYN     rs997368           6  112243291             G
# 197  GS1-124K5.11   rs76949143           7   66009851             A
# 214       RPS6KL1    rs3742785          14   75373034             C
# 177        MED12L   rs11707416           3  151108965             A
# 198         FGF20     rs620513           8   16697593             T
# 217          NOD2    rs6500328          16   50736656             G
# 196         GPNMB     rs199351           7   23300049             C
# 228         MEX3C    rs8087969          18   48683589             G
#
#     other_allele    beta       p_value  effect_allele_frequency    ancestry
# 192            C -0.1605  2.972000e-04                 0.069711  East Asian  \
# 227            G  0.1539  5.900000e-05                 0.884615  East Asian
# 169            G  0.2126  2.910000e-20                 0.519231  East Asian
# 215            T  0.1280  5.560000e-05                 0.829327  East Asian
# 170            T -0.1305  3.180000e-07                 0.264423  East Asian
# 187            G -0.1028  3.004000e-02                 0.060096  East Asian
# 205            C -0.1187  5.820000e-06                 0.269231  East Asian
# 216            G  0.0920  2.580000e-02                 0.949519  East Asian
# 179            T -0.1901  1.100000e-16                 0.608173  East Asian
# 183            C -0.1192  4.380000e-07                 0.379808  East Asian
# 182            T -0.0854  8.808000e-03                 0.144231  East Asian
# 218            C  0.0881  1.503000e-03                 0.817308  East Asian
# 194            A -0.1087  5.570000e-06                 0.360577  East Asian
# 197            T -0.0820  1.051000e-02                 0.153846  East Asian
# 214            A -0.0761  6.151000e-03                 0.216346  East Asian
# 177            T -0.0645  4.794000e-02                 0.120192  East Asian
# 198            G -0.0911  9.200000e-05                 0.444712  East Asian
# 217            A -0.0636  2.556000e-02                 0.218750  East Asian
# 196            A -0.0708  3.291000e-03                 0.310096  East Asian
# 228            T -0.0574  3.056000e-02                 0.269231  East Asian
#
#      eaf_risk  beta_abs risk_allele  odds_ratio_new       par
# 192  0.930288    0.1605           C        1.174098  0.139386
# 227  0.884615    0.1539           T        1.166374  0.128295
# 169  0.519231    0.2126           A        1.236890  0.109528
# 215  0.829327    0.1280           C        1.136553  0.101727
# 170  0.735577    0.1305           T        1.139398  0.093002
# 187  0.939904    0.1028           G        1.108270  0.092364
# 205  0.730769    0.1187           C        1.126032  0.084333
# 216  0.949519    0.0920           A        1.096365  0.083830
# 179  0.391827    0.1901           T        1.209371  0.075817
# 183  0.620192    0.1192           C        1.126595  0.072798
# 182  0.855769    0.0854           T        1.089153  0.070886
# 218  0.817308    0.0881           A        1.092097  0.070003
# 194  0.639423    0.1087           A        1.114828  0.068401
# 197  0.846154    0.0820           T        1.085456  0.067433
# 214  0.783654    0.0761           A        1.079070  0.058348
# 177  0.879808    0.0645           T        1.066626  0.055372
# 198  0.555288    0.0911           G        1.095379  0.050299
# 217  0.781250    0.0636           A        1.065666  0.048798
# 196  0.689904    0.0708           A        1.073367  0.048177
# 228  0.730769    0.0574           T        1.059079  0.041387

# %%
lat = df[df['ancestry'] == 'Latino']

top_lat = lat.nlargest(n=20, columns='par')
top_lat
# Out:
#        Locus          SNP  Chromosome   Position effect_allele other_allele
# 300     MAPT  rs117615688          17   43798308             A            G  \
# 238    KCNS3   rs76116224           2   18147848             T            A
# 256     SNCA     rs356182           4   90626111             A            G
# 294     CHD9   rs10221156          16   52969426             A            G
# 277   RNF141    rs7938782          11   10558777             G            A
# 289   VPS13C    rs2251086          15   61997385             C            T
# 291   SETD1A   rs11150601          16   30977799             A            G
# 252    LCORL   rs34025766           4   17968811             A            T
# 299     MAPT   rs62053943          17   43744203             T            C
# 284    MBNL2    rs4771268          13   97865021             C            T
# 249      GAK     rs873786           4     925376             T            C
# 274    ITGA8     rs896435          10   15557406             T            C
# 239   KCNIP3    rs2042477           2   96000943             T            A
# 281   SCAF11    rs7134559          12   46419086             T            C
# 275     GBF1   rs10748818          10  104015279             G            A
# 246   MED12L   rs11707416           3  151108965             A            T
# 287  RPS6KL1    rs3742785          14   75373034             C            A
# 262   TRIM40    rs9261484           6   30108683             T            C
# 244    IP6K2   rs12497850           3   48748989             T            G
# 283   CAB39L    rs9568188          13   49927732             C            T
#
#          beta       p_value  effect_allele_frequency ancestry  eaf_risk
# 300 -0.740730  2.291157e-04                 0.045562   Latino  0.954438  \
# 238 -0.359278  2.684601e-02                 0.073345   Latino  0.926655
# 256 -0.460053  2.484767e-08                 0.555666   Latino  0.444334
# 294 -0.246284  1.094036e-01                 0.075788   Latino  0.924212
# 277 -0.246127  7.077130e-02                 0.105757   Latino  0.894243
# 289  0.236127  4.489795e-02                 0.855848   Latino  0.855848
# 291  0.278549  9.806977e-04                 0.558559   Latino  0.558559
# 252 -0.181487  1.131676e-01                 0.162728   Latino  0.837272
# 299 -0.157566  3.039939e-01                 0.081547   Latino  0.918453
# 284  0.164418  1.597881e-01                 0.849848   Latino  0.849848
# 249 -0.145887  4.284152e-01                 0.051458   Latino  0.948542
# 274  0.192646  2.817975e-02                 0.673742   Latino  0.673742
# 239  0.195749  2.921862e-02                 0.614394   Latino  0.614394
# 281 -0.153953  9.233683e-02                 0.274674   Latino  0.725326
# 275 -0.128259  2.150136e-01                 0.193466   Latino  0.806534
# 246 -0.142657  1.115378e-01                 0.296694   Latino  0.703306
# 287 -0.136564  1.295589e-01                 0.325148   Latino  0.674852
# 262 -0.148277  9.624725e-02                 0.404453   Latino  0.595547
# 244  0.112949  2.808721e-01                 0.776779   Latino  0.776779
# 283 -0.127131  1.473695e-01                 0.320593   Latino  0.679407
#
#      beta_abs risk_allele  odds_ratio_new       par
# 300  0.740730           G        2.097466  0.511591
# 238  0.359278           A        1.432296  0.286015
# 256  0.460053           G        1.584159  0.206073
# 294  0.246284           G        1.279263  0.205149
# 277  0.246127           A        1.279062  0.199712
# 289  0.236127           C        1.266335  0.185629
# 291  0.278549           A        1.321212  0.152122
# 252  0.181487           T        1.198999  0.142820
# 299  0.157566           C        1.170658  0.135503
# 284  0.164418           C        1.178706  0.131849
# 249  0.145887           C        1.157065  0.129665
# 274  0.192646           T        1.212453  0.125216
# 239  0.195749           T        1.216222  0.117267
# 281  0.153953           C        1.166435  0.107716
# 275  0.128259           A        1.136847  0.099401
# 246  0.142657           T        1.153334  0.097343
# 287  0.136564           A        1.146328  0.089875
# 262  0.148277           C        1.159834  0.086915
# 244  0.112949           T        1.119575  0.084989
# 283  0.127131           T        1.135566  0.084337

# %% [markdown]
# ## T-test

# %%
from scipy import stats
from scipy.stats import ttest_ind

# %%
# Dictionary to map sample size to study (each ancestry is a different study)
study_mapping = {
    'European': 1142025,
    'African/African Admixed': 3645,
    'East Asian': 31575,
    'Latino': 1497
}

# Creating the new column
df['N'] = df['ancestry'].map(study_mapping)

# %%
df_lrrk2 = df[df.Locus == 'LRRK2']
df_lrrk2
# Out:
#      Locus         SNP  Chromosome  Position effect_allele other_allele  \
# 57   LRRK2  rs76904798          12  40220632             T            C
# 58   LRRK2  rs34637584          12  40340400             A            G
# 138  LRRK2  rs76904798          12  40220632             T            C
# 207  LRRK2  rs76904798          12  40614434             T            C
# 280  LRRK2  rs76904798          12  40614434             T            C
#
#          beta        p_value  effect_allele_frequency  \
# 57   0.143900   1.524000e-28                 0.144400
# 58   2.428900  3.610000e-148                 0.001500
# 138  0.090200   2.710000e-01                 0.092500
# 207 -0.020000   7.070000e-01                 0.045673
# 280  0.024496   8.114177e-01                 0.198712
#
#                     ancestry  eaf_risk  beta_abs risk_allele  odds_ratio_new  \
# 57                  European  0.144400  0.143900           T        1.154769
# 58                  European  0.001500  2.428900           A       11.346394
# 138  African/African Admixed  0.092500  0.090200           T        1.094393
# 207               East Asian  0.954327  0.020000           C        1.020201
# 280                   Latino  0.198712  0.024496           T        1.024798
#
#           par        N
# 57   0.021860  1142025
# 58   0.015282  1142025
# 138  0.008656     3645
# 207  0.018914    31575
# 280  0.004904     1497

# %%
df_lrrk2_eur = df_lrrk2[df_lrrk2.ancestry == 'European']
df_lrrk2_afr = df_lrrk2[df_lrrk2.ancestry == 'African/African Admixed']
df_lrrk2_eas = df_lrrk2[df_lrrk2.ancestry == 'East Asian']
df_lrrk2_lat = df_lrrk2[df_lrrk2.ancestry == 'Latino']

print('EUR v AA: ', stats.ttest_ind(df_lrrk2_eur.par, df_lrrk2_afr.par))
print('EUR v EAS: ', stats.ttest_ind(df_lrrk2_eur.par, df_lrrk2_eas.par))
print('EUR v LAT: ', stats.ttest_ind(df_lrrk2_eur.par, df_lrrk2_lat.par))
# Out:
# EUR v AA:  TtestResult(statistic=1.7406513159867456, pvalue=0.3319696007159764, df=1.0)
# EUR v EAS:  TtestResult(statistic=-0.060180655238289575, pvalue=0.9617339566167049, df=1.0)
# EUR v LAT:  TtestResult(statistic=2.3993578304609198, pvalue=0.2513923225565754, df=1.0)

# %%
df_gba1 = df[df.Locus == 'GBA1']

df_gba1_eur = df_gba1[df_gba1.ancestry == 'European']
df_gba1_afr = df_gba1[df_gba1.ancestry == 'African/African Admixed']
df_gba1_eas = df_gba1[df_gba1.ancestry == 'East Asian']
df_gba1_lat = df_gba1[df_gba1.ancestry == 'Latino']

print('EUR v AA: ', stats.ttest_ind(df_gba1_eur.par, df_gba1_afr.par))
print('EUR v EAS: ', stats.ttest_ind(df_gba1_eur.par, df_gba1_eas.par))
print('EUR v LAT: ', stats.ttest_ind(df_gba1_eur.par, df_gba1_lat.par))
# Out:
# EUR v AA:  TtestResult(statistic=nan, pvalue=nan, df=0.0)
# EUR v EAS:  TtestResult(statistic=nan, pvalue=nan, df=0.0)
# EUR v LAT:  TtestResult(statistic=nan, pvalue=nan, df=0.0)

# %%
from itertools import combinations

# %%
# Get unique studies
studies = df['ancestry'].unique()

# Perform pairwise t-tests
results = []
for cat1, cat2 in combinations(studies, 2):
    group1 = df[df['ancestry'] == cat1]['par']
    group2 = df[df['ancestry'] == cat2]['par']
    
    t_stat, p_value = ttest_ind(group1, group2)
    results.append({'Category1': cat1, 'Category2': cat2, 'T-statistic': t_stat, 'P-value': p_value})

# Convert results to DataFrame
results_df = pd.DataFrame(results)

print(results_df)
# Out:
#                  Category1                Category2  T-statistic   P-value
# 0                 European  African/African Admixed     2.300592  0.022666
# 1                 European               East Asian     1.998342  0.047451
# 2                 European                   Latino    -2.232804  0.026891
# 3  African/African Admixed               East Asian    -0.348012  0.728354
# 4  African/African Admixed                   Latino    -3.492760  0.000624
# 5               East Asian                   Latino    -3.147543  0.002007

# %% [markdown]
# ### Generate tables with summary statistics and PAR

# %%
# Top 20, not filtered by p-value
top_all = pd.concat([top_eur, top_afr, top_ea, top_lat])

# %%
# Top 20, filtered by p-value
df_filt = df[df.p_value < 0.05]

eur_filt = df_filt[df_filt['ancestry'] == 'European']
top_eur_filt = eur_filt.nlargest(n=20, columns='par')

afr_filt = df_filt[df_filt['ancestry'] == 'African/African Admixed']
top_afr_filt = afr_filt.nlargest(n=20, columns='par')

ea_filt = df_filt[df_filt['ancestry'] == 'East Asian']
top_ea_filt = ea_filt.nlargest(n=20, columns='par')

lat_filt = df_filt[df_filt['ancestry'] == 'Latino']
top_lat_filt = lat_filt.nlargest(n=20, columns='par')

top_all_filt = pd.concat([top_eur_filt, top_afr_filt, top_ea_filt, top_lat_filt])

# %% [markdown]
# ### Export results to csv

# %%
# Get current date in YYYY-MM-DD format
current_date = datetime.now().strftime('%Y-%m-%d')

# Define the specific path to save the files
save_path = '{WORK_DIR}/PD/results/' 

# List of dataframes and their filenames
dataframes = [(df, f'{current_date}_PD_PAR_results.csv'),
              (top_all, f'{current_date}_PD_PAR_results_top20.csv.csv'),
              (top_all_filt, f'{current_date}_PD_PAR_results_top20_filtered.csv')]

# Export each dataframe to CSV at the specific path
for df, filename in dataframes:
    full_path = os.path.join(save_path, filename)
    df.to_csv(full_path, index=False, header=True)
    print(f'DataFrame exported to {full_path}')
